# %% [markdown]
# Write a Pandas program to display the dimensions or shape of the World alcohol consumption dataset. Also extract the column names from the dataset.

# %%
import pandas as pd

# %%
df=pd.read_csv('wac.csv')
df
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# 4            Beer           1.98
# ..            ...            ...
# 95          Other           0.00
# 96           Wine           7.38
# 97           Wine           0.00
# 98           Wine           0.00
# 99           Wine           0.00
#
# [100 rows x 5 columns]

# %%
df.shape
# Out:
# (100, 5)

# %%
df.iloc[-3:]
# Out:
#     Year       WHO region                                Country  \
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 97           Wine            0.0
# 98           Wine            0.0
# 99           Wine            0.0

# %% [markdown]
# Write a Pandas program to select first 2 rows, 2 columns and specific two columns from World alcohol consumption dataset.

# %%
df.iloc[:2, :2]
# Out:
#    Year       WHO region
# 0  1986  Western Pacific
# 1  1986         Americas

# %%
df.iloc[:2, (df.columns=='Year')]
# Out:
#    Year
# 0  1986
# 1  1986

# %%
df[['Year', 'WHO region']]
# Out:
#     Year       WHO region
# 0   1986  Western Pacific
# 1   1986         Americas
# 2   1985           Africa
# 3   1986         Americas
# 4   1987         Americas
# ..   ...              ...
# 95  1984           Africa
# 96  1985           Europe
# 97  1984  South-East Asia
# 98  1984           Africa
# 99  1985  South-East Asia
#
# [100 rows x 2 columns]

# %% [markdown]
# Write a Pandas program to select random number of rows, fraction of random rows from World alcohol consumption dataset.

# %%
df.sample(frac=0.1)
# Out:
#     Year             WHO region  \
# 3   1986               Americas
# 82  1987                 Europe
# 11  1989               Americas
# 77  1985                 Africa
# 54  1984               Americas
# 26  1985                 Europe
# 88  1987  Eastern Mediterranean
# 7   1985                 Africa
# 29  1986                 Europe
# 78  1989               Americas
#
#                                               Country Beverage Types  \
# 3                                            Colombia           Beer
# 82                                            Ireland        Spirits
# 11                                          Guatemala           Beer
# 77                                           Cameroon        Spirits
# 54                                        El Salvador        Spirits
# 26  United Kingdom of Great Britain and Northern I...           Wine
# 88                                            Lebanon           Beer
# 7                                              Angola        Spirits
# 29                                              Italy          Other
# 78                                            Jamaica          Other
#
#     Display Value
# 3            4.27
# 82           2.25
# 11           0.62
# 77           0.01
# 54           1.81
# 26           1.36
# 88           0.42
# 7            0.39
# 29            NaN
# 78           0.00

# %%
df.sample(5)
# Out:
#     Year             WHO region            Country Beverage Types  \
# 49  1986                 Europe              Malta           Wine
# 98  1984                 Africa  Equatorial Guinea           Wine
# 2   1985                 Africa       Cte d'Ivoire           Wine
# 11  1989               Americas          Guatemala           Beer
# 58  1984  Eastern Mediterranean            Somalia        Spirits
#
#     Display Value
# 49           1.49
# 98           0.00
# 2            1.62
# 11           0.62
# 58           0.00

# %% [markdown]
# Write a Pandas program to find and drop the missing values from World alcohol consumption dataset.

# %%
df1=df.dropna()
df1
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# 4            Beer           1.98
# ..            ...            ...
# 95          Other           0.00
# 96           Wine           7.38
# 97           Wine           0.00
# 98           Wine           0.00
# 99           Wine           0.00
#
# [95 rows x 5 columns]

# %% [markdown]
# Write a Pandas program to remove the duplicates from 'WHO region' column of World alcohol consumption dataset.

# %%
df1=df.drop_duplicates(subset=['WHO region'])
df1
# Out:
#     Year             WHO region       Country Beverage Types  Display Value
# 0   1986        Western Pacific      Viet Nam           Wine           0.00
# 1   1986               Americas       Uruguay          Other           0.50
# 2   1985                 Africa  Cte d'Ivoire           Wine           1.62
# 13  1984  Eastern Mediterranean   Afghanistan          Other           0.00
# 18  1984                 Europe        Norway        Spirits           1.62
# 20  1986        South-East Asia       Myanmar           Wine           0.00

# %% [markdown]
# Write a Pandas program to find out the alcohol consumption of a given year from the world alcohol consumption dataset.

# %%
df1=df[df['Year']==1985]
df1
# Out:
#     Year             WHO region  \
# 2   1985                 Africa
# 7   1985                 Africa
# 12  1985        Western Pacific
# 14  1985        Western Pacific
# 24  1985                 Africa
# 26  1985                 Europe
# 33  1985                 Africa
# 35  1985               Americas
# 44  1985                 Europe
# 50  1985                 Europe
# 63  1985  Eastern Mediterranean
# 71  1985                 Africa
# 76  1985                 Africa
# 77  1985                 Africa
# 80  1985                 Africa
# 81  1985                 Europe
# 85  1985                 Africa
# 94  1985                 Europe
# 96  1985                 Europe
# 99  1985        South-East Asia
#
#                                               Country Beverage Types  \
# 2                                        Cte d'Ivoire           Wine
# 7                                              Angola        Spirits
# 12                   Lao People's Democratic Republic           Beer
# 14                                           Viet Nam        Spirits
# 24                                            Comoros          Other
# 26  United Kingdom of Great Britain and Northern I...           Wine
# 33                                         Mauritania          Other
# 35                              Saint Kitts and Nevis        Spirits
# 44                                          Lithuania          Other
# 50                                        Switzerland          Other
# 63                                              Libya          Other
# 71                                               Mali          Other
# 76                                            Comoros           Beer
# 77                                           Cameroon        Spirits
# 80                                             Malawi          Other
# 81                                        Netherlands           Wine
# 85                   Democratic Republic of the Congo           Wine
# 94                                            Ukraine        Spirits
# 96                                         Luxembourg           Wine
# 99              Democratic People's Republic of Korea           Wine
#
#     Display Value
# 2            1.62
# 7            0.39
# 12           0.00
# 14           0.05
# 24            NaN
# 26           1.36
# 33           0.00
# 35           2.24
# 44            NaN
# 50           0.30
# 63           0.00
# 71           0.57
# 76           0.02
# 77           0.01
# 80           0.84
# 81           2.54
# 85           0.01
# 94           3.06
# 96           7.38
# 99           0.00

# %% [markdown]
# Write a Pandas program to find out the alcohol consumption details in the year '1987'

# %%
df1=df[(df['Year']==1989) | (df['Year']==1987)]
df1.head(10)
# Out:
#     Year       WHO region                Country Beverage Types  Display Value
# 4   1987         Americas  Saint Kitts and Nevis           Beer           1.98
# 5   1987         Americas              Guatemala          Other           0.00
# 6   1987           Africa              Mauritius           Wine           0.13
# 10  1987           Africa               Botswana           Wine           0.20
# 11  1989         Americas              Guatemala           Beer           0.62
# 15  1987           Africa          Guinea-Bissau           Wine           0.07
# 17  1989           Africa             Seychelles           Beer           2.23
# 21  1989         Americas             Costa Rica        Spirits           4.51
# 28  1987  Western Pacific               Viet Nam           Beer           0.11
# 32  1989           Africa              Mauritius           Beer           1.60

# %% [markdown]
# Write a Pandas program to find out the alcohol consumption details by the 'Americas' in the year '1985' from the world alcohol consumption dataset.

# %%
df1=df[(df['Year']==1989) & (df['WHO region']=='Americas')]
df1
# Out:
#     Year WHO region                           Country Beverage Types  \
# 11  1989   Americas                         Guatemala           Beer
# 21  1989   Americas                        Costa Rica        Spirits
# 55  1989   Americas                          Suriname           Wine
# 64  1989   Americas  Bolivia (Plurinational State of)           Beer
# 78  1989   Americas                           Jamaica          Other
#
#     Display Value
# 11           0.62
# 21           4.51
# 55           0.04
# 64           1.26
# 78           0.00

# %% [markdown]
# Write a Pandas program to find out the alcohol consumption details in the year '1986' where WHO region is 'Western Pacific' and country is 'VietNam' from the world alcohol consumption dataset.

# %%
df[(df['Year']==1986) & (df['WHO region']=='Western Pacific') & (df['Country']=='VietNam')]
# Out:
# Empty DataFrame
# Columns: [Year, WHO region, Country, Beverage Types, Display Value]
# Index: []

# %% [markdown]
# Write a Pandas program to find out the alcohol consumption details in the year '1986' or '1989' where WHO region is 'Americas' from the world alcohol consumption dataset.

# %%
df[((df['Year']==1986) | (df['Year']==1989))  & (df['WHO region']=='Americas')].head(10)
# Out:
#     Year WHO region                           Country Beverage Types  \
# 1   1986   Americas                           Uruguay          Other
# 3   1986   Americas                          Colombia           Beer
# 8   1986   Americas               Antigua and Barbuda        Spirits
# 11  1989   Americas                         Guatemala           Beer
# 21  1989   Americas                        Costa Rica        Spirits
# 47  1986   Americas                            Mexico          Other
# 55  1989   Americas                          Suriname           Wine
# 64  1989   Americas  Bolivia (Plurinational State of)           Beer
# 74  1986   Americas  Bolivia (Plurinational State of)        Spirits
# 78  1989   Americas                           Jamaica          Other
#
#     Display Value
# 1            0.50
# 3            4.27
# 8            1.55
# 11           0.62
# 21           4.51
# 47           0.04
# 55           0.04
# 64           1.26
# 74           2.06
# 78           0.00

# %% [markdown]
# Write a Pandas program to find out the alcohol consumption details in the year '1986' or '1989' where WHO region is 'Americas' or 'Europe' from the world alcohol consumption dataset.

# %%
df[((df['Year']==1985) | (df['Year']==1989)) & ((df['WHO region']=='Americas') | (df['WHO region']=='Europe'))].head(10)
# Out:
#     Year WHO region                                            Country  \
# 11  1989   Americas                                          Guatemala
# 21  1989   Americas                                         Costa Rica
# 26  1985     Europe  United Kingdom of Great Britain and Northern I...
# 35  1985   Americas                              Saint Kitts and Nevis
# 44  1985     Europe                                          Lithuania
# 50  1985     Europe                                        Switzerland
# 55  1989   Americas                                           Suriname
# 57  1989     Europe                                            Croatia
# 64  1989   Americas                   Bolivia (Plurinational State of)
# 78  1989   Americas                                            Jamaica
#
#    Beverage Types  Display Value
# 11           Beer           0.62
# 21        Spirits           4.51
# 26           Wine           1.36
# 35        Spirits           2.24
# 44          Other            NaN
# 50          Other           0.30
# 55           Wine           0.04
# 57           Wine           5.10
# 64           Beer           1.26
# 78          Other           0.00

# %% [markdown]
# Write a Pandas program to find out the 'WHO region, 'Country', 'Beverage Types' in the year '1986' or '1989' where WHO region is 'Americas' or 'Europe' from the world alcohol consumption dataset.

# %%
df[((df['Year']==1985) | (df['Year']==1989)) & ((df['WHO region']=='Americas') | (df['WHO region']=='Europe'))][['WHO region','Country','Beverage Types']].head(10)
# Out:
#    WHO region                                            Country  \
# 11   Americas                                          Guatemala
# 21   Americas                                         Costa Rica
# 26     Europe  United Kingdom of Great Britain and Northern I...
# 35   Americas                              Saint Kitts and Nevis
# 44     Europe                                          Lithuania
# 50     Europe                                        Switzerland
# 55   Americas                                           Suriname
# 57     Europe                                            Croatia
# 64   Americas                   Bolivia (Plurinational State of)
# 78   Americas                                            Jamaica
#
#    Beverage Types
# 11           Beer
# 21        Spirits
# 26           Wine
# 35        Spirits
# 44          Other
# 50          Other
# 55           Wine
# 57           Wine
# 64           Beer
# 78          Other

# %% [markdown]
#  Write a Pandas program to find out the records where consumption of beverages per person average >=5 and Beverage Types is Beer from world alcohol consumption dataset.

# %%
df[(df['Display Value'] >= 5) & (df['Beverage Types'] == 'Beer')].head(10)
# Out:
#     Year WHO region         Country Beverage Types  Display Value
# 41  1986     Europe  Czech Republic           Beer           6.82

# %% [markdown]
# Write a Pandas program to find out the records where consumption of beverages per person average >=4 and Beverage Types is Beer, Wine, Spirits from world alcohol consumption dataset.

# %%
df[(df['Display Value'] >= 4) & ((df['Beverage Types'] == 'Beer') | (df['Beverage Types'] == 'Wine')| (df['Beverage Types'] == 'Spirits'))].head(10)
# Out:
#     Year WHO region         Country Beverage Types  Display Value
# 3   1986   Americas        Colombia           Beer           4.27
# 21  1989   Americas      Costa Rica        Spirits           4.51
# 41  1986     Europe  Czech Republic           Beer           6.82
# 57  1989     Europe         Croatia           Wine           5.10
# 91  1989     Europe        Bulgaria           Beer           4.43
# 96  1985     Europe      Luxembourg           Wine           7.38

# %% [markdown]
# Write a Pandas program to filter the specified columns and records by range from world alcohol consumption dataset.

# %%
df.loc[0:4, ['WHO region', 'Year']]
# Out:
#         WHO region  Year
# 0  Western Pacific  1986
# 1         Americas  1986
# 2           Africa  1985
# 3         Americas  1986
# 4         Americas  1987

# %% [markdown]
# Write a Pandas program to filter those records where WHO region contains "Ea" substring from world alcohol consumption dataset.

# %%
df1=df.dropna()
df1
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# 4            Beer           1.98
# ..            ...            ...
# 95          Other           0.00
# 96           Wine           7.38
# 97           Wine           0.00
# 98           Wine           0.00
# 99           Wine           0.00
#
# [95 rows x 5 columns]

# %%
df1[df1['WHO region'].str.contains('Ea')].head(5)
# Out:
#     Year             WHO region      Country Beverage Types  Display Value
# 13  1984  Eastern Mediterranean  Afghanistan          Other           0.00
# 20  1986        South-East Asia      Myanmar           Wine           0.00
# 25  1984  Eastern Mediterranean      Tunisia          Other           0.00
# 27  1984  Eastern Mediterranean      Bahrain           Beer           2.22
# 36  1987  Eastern Mediterranean        Egypt           Beer           0.07

# %% [markdown]
# Write a Pandas program to filter those records where WHO region matches with multiple values (Africa, Eastern Mediterranean, Europe) from world alcohol consumption dataset.

# %%
df[df['WHO region'].isin(['Africa', "Eastern Mediterranean", "Europe"])]
# Out:
#     Year WHO region            Country Beverage Types  Display Value
# 2   1985     Africa       Cte d'Ivoire           Wine           1.62
# 6   1987     Africa          Mauritius           Wine           0.13
# 7   1985     Africa             Angola        Spirits           0.39
# 9   1984     Africa            Nigeria          Other           6.10
# 10  1987     Africa           Botswana           Wine           0.20
# ..   ...        ...                ...            ...            ...
# 93  1987     Africa         Madagascar          Other            NaN
# 94  1985     Europe            Ukraine        Spirits           3.06
# 95  1984     Africa              Niger          Other           0.00
# 96  1985     Europe         Luxembourg           Wine           7.38
# 98  1984     Africa  Equatorial Guinea           Wine           0.00
#
# [69 rows x 5 columns]

# %% [markdown]
# Write a Pandas program to filter all records starting from the 2nd row, access every 5th row from world alcohol consumption dataset.

# %%
df.iloc[1::5]
# Out:
#     Year             WHO region  \
# 1   1986               Americas
# 6   1987                 Africa
# 11  1989               Americas
# 16  1984               Americas
# 21  1989               Americas
# 26  1985                 Europe
# 31  1986        Western Pacific
# 36  1987  Eastern Mediterranean
# 41  1986                 Europe
# 46  1987               Americas
# 51  1987                 Europe
# 56  1987        Western Pacific
# 61  1984        Western Pacific
# 66  1987  Eastern Mediterranean
# 71  1985                 Africa
# 76  1985                 Africa
# 81  1985                 Europe
# 86  1986               Americas
# 91  1989                 Europe
# 96  1985                 Europe
#
#                                               Country Beverage Types  \
# 1                                             Uruguay          Other
# 6                                           Mauritius           Wine
# 11                                          Guatemala           Beer
# 16                                         Costa Rica           Wine
# 21                                         Costa Rica        Spirits
# 26  United Kingdom of Great Britain and Northern I...           Wine
# 31                   Micronesia (Federated States of)           Wine
# 36                                              Egypt           Beer
# 41                                     Czech Republic           Beer
# 46                                Trinidad and Tobago        Spirits
# 51                                            Finland           Beer
# 56                                           Viet Nam           Wine
# 61                                   Papua New Guinea        Spirits
# 66                                               Iraq           Wine
# 71                                               Mali          Other
# 76                                            Comoros           Beer
# 81                                        Netherlands           Wine
# 86                                            Bahamas           Wine
# 91                                           Bulgaria           Beer
# 96                                         Luxembourg           Wine
#
#     Display Value
# 1            0.50
# 6            0.13
# 11           0.62
# 16           0.06
# 21           4.51
# 26           1.36
# 31           0.00
# 36           0.07
# 41           6.82
# 46           2.26
# 51           3.88
# 56           0.00
# 61           0.08
# 66           0.01
# 71           0.57
# 76           0.02
# 81           2.54
# 86           1.83
# 91           4.43
# 96           7.38

# %%
df.iloc[1::5, 0::2]
# Out:
#     Year                                            Country  Display Value
# 1   1986                                            Uruguay           0.50
# 6   1987                                          Mauritius           0.13
# 11  1989                                          Guatemala           0.62
# 16  1984                                         Costa Rica           0.06
# 21  1989                                         Costa Rica           4.51
# 26  1985  United Kingdom of Great Britain and Northern I...           1.36
# 31  1986                   Micronesia (Federated States of)           0.00
# 36  1987                                              Egypt           0.07
# 41  1986                                     Czech Republic           6.82
# 46  1987                                Trinidad and Tobago           2.26
# 51  1987                                            Finland           3.88
# 56  1987                                           Viet Nam           0.00
# 61  1984                                   Papua New Guinea           0.08
# 66  1987                                               Iraq           0.01
# 71  1985                                               Mali           0.57
# 76  1985                                            Comoros           0.02
# 81  1985                                        Netherlands           2.54
# 86  1986                                            Bahamas           1.83
# 91  1989                                           Bulgaria           4.43
# 96  1985                                         Luxembourg           7.38

# %% [markdown]
#  Write a Pandas program to filter all records starting from the 'Year' column, access every other column from world alcohol consumption dataset.

# %%
df.iloc[:, 0::2]
# Out:
#     Year                                Country  Display Value
# 0   1986                               Viet Nam           0.00
# 1   1986                                Uruguay           0.50
# 2   1985                           Cte d'Ivoire           1.62
# 3   1986                               Colombia           4.27
# 4   1987                  Saint Kitts and Nevis           1.98
# ..   ...                                    ...            ...
# 95  1984                                  Niger           0.00
# 96  1985                             Luxembourg           7.38
# 97  1984                              Indonesia           0.00
# 98  1984                      Equatorial Guinea           0.00
# 99  1985  Democratic People's Republic of Korea           0.00
#
# [100 rows x 3 columns]

# %% [markdown]
# Write a Pandas program to filter all columns where all entries present, check which rows and columns has a NaN and finally drop rows with any NaNs from world alcohol consumption dataset.

# %%
df.dropna(how='any')
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# 4            Beer           1.98
# ..            ...            ...
# 95          Other           0.00
# 96           Wine           7.38
# 97           Wine           0.00
# 98           Wine           0.00
# 99           Wine           0.00
#
# [95 rows x 5 columns]

# %% [markdown]
#  Write a Pandas program to find which years have all non-zero values and which years have any non-zero values from world alcohol consumption dataset.

# %%
df.loc[:, df.all()]
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types
# 0            Wine
# 1           Other
# 2            Wine
# 3            Beer
# 4            Beer
# ..            ...
# 95          Other
# 96           Wine
# 97           Wine
# 98           Wine
# 99           Wine
#
# [100 rows x 4 columns]

# %%
df.loc[:, df.any()]
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# 4            Beer           1.98
# ..            ...            ...
# 95          Other           0.00
# 96           Wine           7.38
# 97           Wine           0.00
# 98           Wine           0.00
# 99           Wine           0.00
#
# [100 rows x 5 columns]

# %% [markdown]
# Write a Pandas program to rename all and only some of the column names from world alcohol consumption dataset.

# %%
df.columns = ['year','who_region','country','beverage_types','display_values']
df
# Out:
#     year       who_region                                country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    beverage_types  display_values
# 0            Wine            0.00
# 1           Other            0.50
# 2            Wine            1.62
# 3            Beer            4.27
# 4            Beer            1.98
# ..            ...             ...
# 95          Other            0.00
# 96           Wine            7.38
# 97           Wine            0.00
# 98           Wine            0.00
# 99           Wine            0.00
#
# [100 rows x 5 columns]

# %%
df.rename(columns = {"WHO region":"WHO_region","Display Value":"Display_Value" },inplace = True)
df
# Out:
#     year       who_region                                country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    beverage_types  display_values
# 0            Wine            0.00
# 1           Other            0.50
# 2            Wine            1.62
# 3            Beer            4.27
# 4            Beer            1.98
# ..            ...             ...
# 95          Other            0.00
# 96           Wine            7.38
# 97           Wine            0.00
# 98           Wine            0.00
# 99           Wine            0.00
#
# [100 rows x 5 columns]

# %% [markdown]
# 22. Write a Pandas program to select consecutive columns and also select rows with Index label 0 to 9 with some columns from world alcohol consumption dataset.

# %%
df.iloc[:,2:5].head()
# Out:
#                  country beverage_types  display_values
# 0               Viet Nam           Wine            0.00
# 1                Uruguay          Other            0.50
# 2           Cte d'Ivoire           Wine            1.62
# 3               Colombia           Beer            4.27
# 4  Saint Kitts and Nevis           Beer            1.98

# %%
df.loc[0:9,["year","country"]]
# Out:
#    year                country
# 0  1986               Viet Nam
# 1  1986                Uruguay
# 2  1985           Cte d'Ivoire
# 3  1986               Colombia
# 4  1987  Saint Kitts and Nevis
# 5  1987              Guatemala
# 6  1987              Mauritius
# 7  1985                 Angola
# 8  1986    Antigua and Barbuda
# 9  1984                Nigeria

# %% [markdown]
# Write a Pandas program to filter rows based on row numbers ended with 0, like 0, 10, 20, 30 from world alcohol consumption dataset.

# %%
df.filter(regex='0$', axis=0)
# Out:
#     year             who_region                     country beverage_types  \
# 0   1986        Western Pacific                    Viet Nam           Wine
# 10  1987                 Africa                    Botswana           Wine
# 20  1986        South-East Asia                     Myanmar           Wine
# 30  1986                 Africa                Sierra Leone          Other
# 40  1987                 Europe                     Austria        Spirits
# 50  1985                 Europe                 Switzerland          Other
# 60  1987  Eastern Mediterranean  Iran (Islamic Republic of)          Other
# 70  1986                 Africa                  Madagascar        Spirits
# 80  1985                 Africa                      Malawi          Other
# 90  1989                 Africa                      Malawi           Wine
#
#     display_values
# 0             0.00
# 10            0.20
# 20            0.00
# 30            4.48
# 40            1.90
# 50            0.30
# 60            0.00
# 70            1.02
# 80            0.84
# 90            0.01

# %%
df.filter(regex='1$', axis=0)
# Out:
#     year       who_region                           country beverage_types  \
# 1   1986         Americas                           Uruguay          Other
# 11  1989         Americas                         Guatemala           Beer
# 21  1989         Americas                        Costa Rica        Spirits
# 31  1986  Western Pacific  Micronesia (Federated States of)           Wine
# 41  1986           Europe                    Czech Republic           Beer
# 51  1987           Europe                           Finland           Beer
# 61  1984  Western Pacific                  Papua New Guinea        Spirits
# 71  1985           Africa                              Mali          Other
# 81  1985           Europe                       Netherlands           Wine
# 91  1989           Europe                          Bulgaria           Beer
#
#     display_values
# 1             0.50
# 11            0.62
# 21            4.51
# 31            0.00
# 41            6.82
# 51            3.88
# 61            0.08
# 71            0.57
# 81            2.54
# 91            4.43

# %% [markdown]
# Write a Pandas program to find average consumption of wine per person greater than 2 in world alcohol consumption dataset.

# %%
df[(df['Beverage Types'] == 'Wine') & (df['Display Value'] > .2)].count()
# Out:
# Year              9
# WHO region        9
# Country           9
# Beverage Types    9
# Display Value     9
# dtype: int64

# %% [markdown]
# Write a Pandas program to filter all records where the average consumption of beverages per person from .5 to 2.50 in world alcohol consumption dataset.

# %%
df[(df['Display Value'] < 2.5) & (df['Display Value']>.5)].head()
# Out:
#     Year WHO region                Country Beverage Types  Display Value
# 2   1985     Africa           Cte d'Ivoire           Wine           1.62
# 4   1987   Americas  Saint Kitts and Nevis           Beer           1.98
# 8   1986   Americas    Antigua and Barbuda        Spirits           1.55
# 11  1989   Americas              Guatemala           Beer           0.62
# 17  1989     Africa             Seychelles           Beer           2.23

# %% [markdown]
# Write a Pandas program to filter those records which not appears in a given list from world alcohol consumption dataset.

# %%
who_region = ["Africa", "Eastern Mediterranean", "Europe"]
flt_wine = ~df["WHO region"].isin(who_region)
df[flt_wine]
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# 5   1987         Americas                              Guatemala
# 8   1986         Americas                    Antigua and Barbuda
# 11  1989         Americas                              Guatemala
# 12  1985  Western Pacific       Lao People's Democratic Republic
# 14  1985  Western Pacific                               Viet Nam
# 16  1984         Americas                             Costa Rica
# 20  1986  South-East Asia                                Myanmar
# 21  1989         Americas                             Costa Rica
# 28  1987  Western Pacific                               Viet Nam
# 31  1986  Western Pacific       Micronesia (Federated States of)
# 35  1985         Americas                  Saint Kitts and Nevis
# 43  1984  Western Pacific                                  China
# 46  1987         Americas                    Trinidad and Tobago
# 47  1986         Americas                                 Mexico
# 48  1987         Americas                              Nicaragua
# 54  1984         Americas                            El Salvador
# 55  1989         Americas                               Suriname
# 56  1987  Western Pacific                               Viet Nam
# 61  1984  Western Pacific                       Papua New Guinea
# 62  1987         Americas                               Suriname
# 64  1989         Americas       Bolivia (Plurinational State of)
# 74  1986         Americas       Bolivia (Plurinational State of)
# 78  1989         Americas                                Jamaica
# 84  1986  South-East Asia                              Sri Lanka
# 86  1986         Americas                                Bahamas
# 97  1984  South-East Asia                              Indonesia
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 3            Beer           4.27
# 4            Beer           1.98
# 5           Other           0.00
# 8         Spirits           1.55
# 11           Beer           0.62
# 12           Beer           0.00
# 14        Spirits           0.05
# 16           Wine           0.06
# 20           Wine           0.00
# 21        Spirits           4.51
# 28           Beer           0.11
# 31           Wine           0.00
# 35        Spirits           2.24
# 43           Wine           0.03
# 46        Spirits           2.26
# 47          Other           0.04
# 48           Beer           0.70
# 54        Spirits           1.81
# 55           Wine           0.04
# 56           Wine           0.00
# 61        Spirits           0.08
# 62          Other           0.00
# 64           Beer           1.26
# 74        Spirits           2.06
# 78          Other           0.00
# 84          Other           0.00
# 86           Wine           1.83
# 97           Wine           0.00
# 99           Wine           0.00
